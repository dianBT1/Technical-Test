# %%
test = points=[ScoredPoint(id='e3cbd98e-8f69-4c87-b7c9-d15da0e77e2e', version=2, score=1.0, payload={'text': 'dian suka ikan'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='b8a2db2c-ad33-471f-8329-718e491cebc9', version=1, score=0.77841926, payload={'text': 'liana suka ayam'}, vector=None, shard_key=None, order_value=None)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 test = points=[ScoredPoint(id='e3cbd98e-8f69-4c87-b7c9-d15da0e77e2e', version=2, score=1.0, payload={'text': 'dian suka ikan'}, vector=None, shard_key=None, order_value=None), ScoredPoint(id='b8a2db2c-ad33-471f-8329-718e491cebc9', version=1, score=0.77841926, payload={'text': 'liana suka ayam'}, vector=None, shard_key=None, order_value=None)]
#
# NameError: name 'ScoredPoint' is not defined
